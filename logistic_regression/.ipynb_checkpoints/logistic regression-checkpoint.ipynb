# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data preparation

# %%
mean_01 = ([1, .5])
cov_01 = ([[1, .1], [.1, 1.4]])

mean_02 = ([3, 4.5])
cov_02 = ([[1.2, .1], [.1, 1.3]])

# %%
dist_01 = np.random.multivariate_normal(mean_01, cov_01, 500)
dist_02 = np.random.multivariate_normal(mean_02, cov_02, 500)

# %% [markdown]
# ## Visualize

# %%
plt.scatter(dist_01[:, 0], dist_01[:, 1])
plt.scatter(dist_02[:, 0], dist_02[:, 1], color = "red")
plt.show()

# %% [markdown]
# ## Data preprocessing

# %%
total = dist_01.shape[0] + dist_02.shape[0]
print(total)
# Out:
# 1000

# %%
data = np.zeros((total, 3))

# %%
data[:500, :-1] = dist_01
data[500:, :-1] = dist_02
data[500:, -1] = 1

# %%
np.random.shuffle(data)

# %%
# Normalizing
u = np.mean(data[:, :-1])
sigma = np.std(data[:, :-1])

data[:, :-1] = (data[:, :-1] - u)/sigma

# %%
print(data)
# Out:
# [[-1.42272695  0.35990101  0.        ]
#  [-0.74399246 -0.89422593  0.        ]
#  [-0.87355981 -2.51973303  0.        ]
#  ...
#  [-0.27510865 -0.08326989  0.        ]
#  [-0.62044393 -0.63133952  0.        ]
#  [ 0.47730349  0.8882336   1.        ]]

# %%
ones = np.ones((data.shape[0], 1))

# %%
data = np.hstack((ones, data))

# %%
print(data)
# Out:
# [[ 1.         -1.42272695  0.35990101  0.        ]
#  [ 1.         -0.74399246 -0.89422593  0.        ]
#  [ 1.         -0.87355981 -2.51973303  0.        ]
#  ...
#  [ 1.         -0.27510865 -0.08326989  0.        ]
#  [ 1.         -0.62044393 -0.63133952  0.        ]
#  [ 1.          0.47730349  0.8882336   1.        ]]

# %%
plt.scatter(data[:, 1], data[:, 2], c = data[:, 3])
plt.show()

# %%
split = int(.8*total)

# %%
x_train = data[:split, :-1]
y_train = data[:split, -1]

x_test = data[split:, :-1]
y_test = data[split:, -1]

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (800, 3) (800,)
# (200, 3) (200,)

# %% [markdown]
# ## Logistic Regression

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
def hypothesis(x, theta):
    return sigmoid(np.dot(x, theta))

# %%
def error(x, y, theta):
    
    m = x.shape[0]
    err = 0
    
    for i in range(m):
        hy = hypothesis(x[i], theta)
        err += y[i]*np.log2(hy) + (1 - y[i])*np.log2(1 - hy)
        
    return err/m

# %%
def get_grad(x, y, theta):
    
    m = x.shape[0]
    grad = np.zeros(theta.shape)
    
    for i in range(m):
        hy = hypothesis(x[i], theta)
        x = x[i].reshape((-1, 1))
        grad += (y[i] - hy)*x
        
    return grad/m

# %%
def gradient(x, y, learining_rate = .01):
    
    theta = np.zeros((x.shape[1], 1))
    
    err_list = []
    
    for i in range(300):
        theta = theta + learining_rate*get_grad(x, y, theta)
        e = error(x, y, theta)
        err_list.append(e)
        
    return theta, err_list

# %%
ftheta, error = gradient(x_train, y_train)
print(ftheta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-49129feaebe1> in <module>
# ----> 1 ftheta, error = gradient(x_train, y_train)
#       2 print(ftheta)
#
# <ipython-input-87-1c726355e45c> in gradient(x, y, learining_rate)
#       6
#       7     for i in range(300):
# ----> 8         theta = theta + learining_rate*get_grad(x, y, theta)
#       9         e = error(x, y, theta)
#      10         err_list.append(e)
#
# <ipython-input-84-72932e2288ec> in get_grad(x, y, theta)
#       6     for i in range(m):
#       7         hy = hypothesis(x[i], theta)
# ----> 8         x[i] = x[i].reshape((-1, 1))
#       9         print(x[i].shape)
#      10         grad += (y[i] - hy)*x[i]
#
# ValueError: could not broadcast input array from shape (3,1) into shape (3)
